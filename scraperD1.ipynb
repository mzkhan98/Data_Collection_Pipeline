# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time, datetime
import pandas as pd
import os
import boto3



#------------- Scraper Class---------------
class Scraper: 

    #------------- Initiate Chrome Browser---------------
    def __init__(self,url:str = 'https://www.hotukdeals.com/tag/electronics?page=1'):
        self.listofdict = list()
        options = webdriver.ChromeOptions() 
        options.add_argument("start-maximized")
        options.add_experimental_option("excludeSwitches", ["enable-automation"])
        options.add_experimental_option('useAutomationExtension', False)
        options.add_argument('--disable-blink-features=AutomationControlled')
        prefs = {"profile.default_content_setting_values.notifications" : 2}
        options.add_experimental_option("prefs",prefs)
        self.driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
        self.driver.get(url)

    #------------- Accept the Cookies---------------
    def accecept_cookies(self):
        try:
            time.sleep(5)
            self.driver.find_element(By.XPATH,'//button[@data-t="acceptAllBtn"]').click()
        except TimeoutException:
            print('No Cookies Found')

    #------------- Data Scrape from Container & Move to Next Page---------------
    def find_container(self):
        driver = self.driver
        time.sleep(5)
        #count the number of pages
        count = 0
        for pagenum in range(1,501):
            driver.get(f'https://www.hotukdeals.com/tag/electronics?page={pagenum}')
            time.sleep(5)
            #list the page container
            productcontainer = driver.find_elements(By.XPATH, '//article[@data-t="thread"]')
            print(len(productcontainer))        
            for singleproduct in productcontainer: 
                #dict to store data temporary          
                datadict = dict()
                try:datadict['Image'] = singleproduct.find_element(By.XPATH, './/img').get_attribute('src')
                except:datadict['Image'] = ''
                try:datadict['Title'] = singleproduct.find_element(By.XPATH, './/strong[@class="thread-title "]/a').text
                except:datadict['Title'] = ''
                try:datadict['Link'] = singleproduct.find_element(By.XPATH, './/a[@rel="nofollow noopener"]').get_attribute('href')
                except:
                    try:datadict['Link'] = singleproduct.find_element(By.XPATH, './/a[@rel="nofollow"]').get_attribute('href')
                    except:datadict['Link'] = ''
                try:datadict['Price'] = singleproduct.find_element(By.XPATH, './/span[@class="overflow--wrap-off"]/span').text
                except:datadict['Price'] = ''
                print(datadict)
                #append data in main list
                self.listofdict.append(datadict)
            #add the value for page number counting
            count+= 1
            #here you can set number of pages
            if count == 1:
                break
        time.sleep(5)
        driver.quit()
    
    #------------- Save Data ---------------
    def save_data(self):
        date = datetime.datetime.now().strftime("%d-%m-%Y-%H-%M-%S")
        df = pd.DataFrame.from_dict(self.listofdict)
        print('\n\n  ************DATA FRAME**************')
        print(df)
        df.to_csv(f'HotukDeals-{date}.csv',index=False)
        df.to_json(f'HotukDeals-{date}.json')        
        print('Saved Data in CSV!!')
    
    def upload_data(self):
        s3 = boto3.client('s3')
        s3.upload_file('HotukDeals-{date}.csv','dealsuk2022', 'Hotukdeals-{date}.csv')
        
            



if __name__ == "__main__":
    bot = Scraper()
    bot.accecept_cookies()
    try:
        bot.find_container()
        bot.save_data()
        bot.upload_data()
    except:
        bot.save_data()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/home/zain/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache
# /tmp/ipykernel_1789283/1847976215.py:27: DeprecationWarning: use options instead of chrome_options
#   self.driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
# 20
# {'Image': 'https://images.hotukdeals.com/threads/raw/j2sgo/3955168_1/re/300x300/qt/60/3955168_1.jpg', 'Title': 'BRAIDED 20AWG USB PD Type C To 8 Pin Lightning FAST CHARGE Charging Cable 1m - £3.63 Delivered @ kenable', 'Link': 'https://www.hotukdeals.com/visit/thread/3955168', 'Price': '£3.63'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/MMmPg/3955147_1/re/300x300/qt/60/3955147_1.jpg', 'Title': 'MyMemory 128GB USB 3.0 Flash Drive - Red - 100MB/s - £9.99 @ MyMemory', 'Link': 'https://www.hotukdeals.com/visit/thread/3955147', 'Price': '£9.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/zmiQ5/3955099_1/re/300x300/qt/60/3955099_1.jpg', 'Title': 'Sony SRS-RA3000 Home Speaker with Wi-Fi - £189 @ John Lewis', 'Link': 'https://www.hotukdeals.com/visit/thread/3955099', 'Price': '£189'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/yR5D0/3955041_1/re/300x300/qt/60/3955041_1.jpg', 'Title': 'Belkin RT3200 WiFi 6 Router AX3200 - £49.98 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955041', 'Price': '£49.98'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/HYRwl/3955165_1/re/300x300/qt/60/3955165_1.jpg', 'Title': 'Philips Ambilight 65OLED805/12 65-Inch OLED TV (4K UHD, P5 AI Perfect Picture Engine, Dolby Vision, Dolby Atmos, Android TV) £997.95 Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955165', 'Price': '£997.95'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/z4fsO/3955016_1/re/300x300/qt/60/3955016_1.jpg', 'Title': 'Team Group 64 GB UHS-I Micro-SD Flash Memory Card MicroSDHC Temporarily out of stock £4.79 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955016', 'Price': '£4.79'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/wNNhw/3955143_1/re/300x300/qt/60/3955143_1.jpg', 'Title': 'Samsung Galaxy Tab A8 10.5” Screen Wi-Fi Android Tablet 32GB Grey £130.35 (Using code / First time via app) @ Amazon Italy', 'Link': 'https://www.hotukdeals.com/visit/thread/3955143', 'Price': '£130.35'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/4gf4e/3955146_1/re/300x300/qt/60/3955146_1.jpg', 'Title': 'NZXT H510i - Compact ATX Mid-Tower PC Gaming Case £55.16 @ Amazon Germany', 'Link': 'https://www.hotukdeals.com/visit/thread/3955146', 'Price': '£55.16'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/9lNQe/3955127_1/re/300x300/qt/60/3955127_1.jpg', 'Title': 'AMD Ryzen 5 5600X Processor (6C/12T, 35MB Cache, up to 4.6 GHz Max Boost) £178.50 @ Amazon Spain', 'Link': 'https://www.hotukdeals.com/visit/thread/3955127', 'Price': '£178.50'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/RJeNk/3955065_1/re/300x300/qt/60/3955065_1.jpg', 'Title': 'Philips 243V7QDAB price drop £97.49 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955065', 'Price': '£97.49'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/0sg01/3955113_1/re/300x300/qt/60/3955113_1.jpg', 'Title': 'EXCLUSIVEAukey PA-Y25 20W Power Delivery USB-C Mini Charger - £6.63 Delivered With Code @ MyMemory', 'Link': 'https://www.hotukdeals.com/visit/thread/3955113', 'Price': '£6.63'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/Wo9OO/3955083_1/re/300x300/qt/60/3955083_1.jpg', 'Title': 'Sony WH-1000XM5 Wireless Noise Cancelling Headphones - £289.76 (with code/1st time via App) / £300.33 w/out code, UK Mainland @ Amazon Italy', 'Link': 'https://www.hotukdeals.com/visit/thread/3955083', 'Price': '£289.76'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/iLZSS/3955034_1/re/300x300/qt/60/3955034_1.jpg', 'Title': 'Samsung 55” AU7100 UHD 4K HDR Smart TV (2021) - £306.05 with code @ Samsung EPP', 'Link': 'https://www.hotukdeals.com/visit/thread/3955034', 'Price': '£306.05'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/l6fbv/3955053_1/re/300x300/qt/60/3955053_1.jpg', 'Title': 'Garmin Fenix 7 solar - £482.12 @ Amazon Germany', 'Link': 'https://www.hotukdeals.com/visit/thread/3955053', 'Price': '£482.12'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/R2KOG/3954979_1/re/300x300/qt/60/3954979_1.jpg', 'Title': 'SoundPEATS Bluetooth5.2 Wireless Bluetooth Earphones £19.99 with automatic discount & voucher Dispatches from Amazon Sold by YXM-EU', 'Link': 'https://www.hotukdeals.com/visit/thread/3954979', 'Price': '£19.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/BtJpb/3955017_1/re/300x300/qt/60/3955017_1.jpg', 'Title': 'Redmi Note 10 Pro 6GB+128GB Smartphone - 6.67” 120Hz AMOLED DotDisplay + Redmi Buds 3 Pro - £174 via App @ Xiaomi UK', 'Link': 'https://www.hotukdeals.com/visit/thread/3955017', 'Price': '£174'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/GU9d1/3954904_1/re/300x300/qt/60/3954904_1.jpg', 'Title': 'MSI Katana GF66 15.6" Gaming Laptop - Intel Core i7, RTX 3070, 512 GB SSD - £999 delivered @ Currys', 'Link': 'https://www.hotukdeals.com/visit/thread/3954904', 'Price': '£999'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/o9Lji/3954963_1/re/300x300/qt/60/3954963_1.jpg', 'Title': 'Hisense A7200GTUK Roku Smart 4K HDR LED Freeview TV 50" £275 55" - £325 Delivered @ QVC UK', 'Link': 'https://www.hotukdeals.com/visit/thread/3954963', 'Price': '£275'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/lcIHo/3954974_1/re/300x300/qt/60/3954974_1.jpg', 'Title': 'Used NVIDIA GeForce GTX 1050 2GB GDDR5 - £60 delivered @ CEX', 'Link': 'https://www.hotukdeals.com/visit/thread/3954974', 'Price': '£60'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/GknEU/3954971_1/re/300x300/qt/60/3954971_1.jpg', 'Title': 'Hisense 50A7500FTUK (2020) LED HDR 4K Ultra HD Smart TV, 50 inch with Freeview Play - £249 instore @ John Lewis & Partners, Cambridge', 'Link': '', 'Price': '£249'}
#
#
#   ************DATA FRAME**************
#                                                 Image  \
# 0   https://images.hotukdeals.com/threads/raw/j2sg...
# 1   https://images.hotukdeals.com/threads/raw/MMmP...
# 2   https://images.hotukdeals.com/threads/raw/zmiQ...
# 3   https://images.hotukdeals.com/threads/raw/yR5D...
# 4   https://images.hotukdeals.com/threads/raw/HYRw...
# 5   https://images.hotukdeals.com/threads/raw/z4fs...
# 6   https://images.hotukdeals.com/threads/raw/wNNh...
# 7   https://images.hotukdeals.com/threads/raw/4gf4...
# 8   https://images.hotukdeals.com/threads/raw/9lNQ...
# 9   https://images.hotukdeals.com/threads/raw/RJeN...
# 10  https://images.hotukdeals.com/threads/raw/0sg0...
# 11  https://images.hotukdeals.com/threads/raw/Wo9O...
# 12  https://images.hotukdeals.com/threads/raw/iLZS...
# 13  https://images.hotukdeals.com/threads/raw/l6fb...
# 14  https://images.hotukdeals.com/threads/raw/R2KO...
# 15  https://images.hotukdeals.com/threads/raw/BtJp...
# 16  https://images.hotukdeals.com/threads/raw/GU9d...
# 17  https://images.hotukdeals.com/threads/raw/o9Lj...
# 18  https://images.hotukdeals.com/threads/raw/lcIH...
# 19  https://images.hotukdeals.com/threads/raw/GknE...
#
#                                                 Title  \
# 0   BRAIDED 20AWG USB PD Type C To 8 Pin Lightning...
# 1   MyMemory 128GB USB 3.0 Flash Drive - Red - 100...
# 2   Sony SRS-RA3000 Home Speaker with Wi-Fi - £189...
# 3   Belkin RT3200 WiFi 6 Router AX3200 - £49.98 @ ...
# 4   Philips Ambilight 65OLED805/12 65-Inch OLED TV...
# 5   Team Group 64 GB UHS-I Micro-SD Flash Memory C...
# 6   Samsung Galaxy Tab A8 10.5” Screen Wi-Fi Andro...
# 7   NZXT H510i - Compact ATX Mid-Tower PC Gaming C...
# 8   AMD Ryzen 5 5600X Processor (6C/12T, 35MB Cach...
# 9        Philips 243V7QDAB price drop £97.49 @ Amazon
# 10  EXCLUSIVEAukey PA-Y25 20W Power Delivery USB-C...
# 11  Sony WH-1000XM5 Wireless Noise Cancelling Head...
# 12  Samsung 55” AU7100 UHD 4K HDR Smart TV (2021) ...
# 13    Garmin Fenix 7 solar - £482.12 @ Amazon Germany
# 14  SoundPEATS Bluetooth5.2 Wireless Bluetooth Ear...
# 15  Redmi Note 10 Pro 6GB+128GB Smartphone - 6.67”...
# 16  MSI Katana GF66 15.6" Gaming Laptop - Intel Co...
# 17  Hisense A7200GTUK Roku Smart 4K HDR LED Freevi...
# 18  Used NVIDIA GeForce GTX 1050 2GB GDDR5 - £60 d...
# 19  Hisense 50A7500FTUK (2020) LED HDR 4K Ultra HD...
#
#                                                Link    Price
# 0   https://www.hotukdeals.com/visit/thread/3955168    £3.63
# 1   https://www.hotukdeals.com/visit/thread/3955147    £9.99
# 2   https://www.hotukdeals.com/visit/thread/3955099     £189
# 3   https://www.hotukdeals.com/visit/thread/3955041   £49.98
# 4   https://www.hotukdeals.com/visit/thread/3955165  £997.95
# 5   https://www.hotukdeals.com/visit/thread/3955016    £4.79
# 6   https://www.hotukdeals.com/visit/thread/3955143  £130.35
# 7   https://www.hotukdeals.com/visit/thread/3955146   £55.16
# 8   https://www.hotukdeals.com/visit/thread/3955127  £178.50
# 9   https://www.hotukdeals.com/visit/thread/3955065   £97.49
# 10  https://www.hotukdeals.com/visit/thread/3955113    £6.63
# 11  https://www.hotukdeals.com/visit/thread/3955083  £289.76
# 12  https://www.hotukdeals.com/visit/thread/3955034  £306.05
# 13  https://www.hotukdeals.com/visit/thread/3955053  £482.12
# 14  https://www.hotukdeals.com/visit/thread/3954979   £19.99
# 15  https://www.hotukdeals.com/visit/thread/3955017     £174
# 16  https://www.hotukdeals.com/visit/thread/3954904     £999
# 17  https://www.hotukdeals.com/visit/thread/3954963     £275
# 18  https://www.hotukdeals.com/visit/thread/3954974      £60
# 19                                                      £249
# Saved Data in CSV!!
#
#
#   ************DATA FRAME**************
#                                                 Image  \
# 0   https://images.hotukdeals.com/threads/raw/j2sg...
# 1   https://images.hotukdeals.com/threads/raw/MMmP...
# 2   https://images.hotukdeals.com/threads/raw/zmiQ...
# 3   https://images.hotukdeals.com/threads/raw/yR5D...
# 4   https://images.hotukdeals.com/threads/raw/HYRw...
# 5   https://images.hotukdeals.com/threads/raw/z4fs...
# 6   https://images.hotukdeals.com/threads/raw/wNNh...
# 7   https://images.hotukdeals.com/threads/raw/4gf4...
# 8   https://images.hotukdeals.com/threads/raw/9lNQ...
# 9   https://images.hotukdeals.com/threads/raw/RJeN...
# 10  https://images.hotukdeals.com/threads/raw/0sg0...
# 11  https://images.hotukdeals.com/threads/raw/Wo9O...
# 12  https://images.hotukdeals.com/threads/raw/iLZS...
# 13  https://images.hotukdeals.com/threads/raw/l6fb...
# 14  https://images.hotukdeals.com/threads/raw/R2KO...
# 15  https://images.hotukdeals.com/threads/raw/BtJp...
# 16  https://images.hotukdeals.com/threads/raw/GU9d...
# 17  https://images.hotukdeals.com/threads/raw/o9Lj...
# 18  https://images.hotukdeals.com/threads/raw/lcIH...
# 19  https://images.hotukdeals.com/threads/raw/GknE...
#
#                                                 Title  \
# 0   BRAIDED 20AWG USB PD Type C To 8 Pin Lightning...
# 1   MyMemory 128GB USB 3.0 Flash Drive - Red - 100...
# 2   Sony SRS-RA3000 Home Speaker with Wi-Fi - £189...
# 3   Belkin RT3200 WiFi 6 Router AX3200 - £49.98 @ ...
# 4   Philips Ambilight 65OLED805/12 65-Inch OLED TV...
# 5   Team Group 64 GB UHS-I Micro-SD Flash Memory C...
# 6   Samsung Galaxy Tab A8 10.5” Screen Wi-Fi Andro...
# 7   NZXT H510i - Compact ATX Mid-Tower PC Gaming C...
# 8   AMD Ryzen 5 5600X Processor (6C/12T, 35MB Cach...
# 9        Philips 243V7QDAB price drop £97.49 @ Amazon
# 10  EXCLUSIVEAukey PA-Y25 20W Power Delivery USB-C...
# 11  Sony WH-1000XM5 Wireless Noise Cancelling Head...
# 12  Samsung 55” AU7100 UHD 4K HDR Smart TV (2021) ...
# 13    Garmin Fenix 7 solar - £482.12 @ Amazon Germany
# 14  SoundPEATS Bluetooth5.2 Wireless Bluetooth Ear...
# 15  Redmi Note 10 Pro 6GB+128GB Smartphone - 6.67”...
# 16  MSI Katana GF66 15.6" Gaming Laptop - Intel Co...
# 17  Hisense A7200GTUK Roku Smart 4K HDR LED Freevi...
# 18  Used NVIDIA GeForce GTX 1050 2GB GDDR5 - £60 d...
# 19  Hisense 50A7500FTUK (2020) LED HDR 4K Ultra HD...
#
#                                                Link    Price
# 0   https://www.hotukdeals.com/visit/thread/3955168    £3.63
# 1   https://www.hotukdeals.com/visit/thread/3955147    £9.99
# 2   https://www.hotukdeals.com/visit/thread/3955099     £189
# 3   https://www.hotukdeals.com/visit/thread/3955041   £49.98
# 4   https://www.hotukdeals.com/visit/thread/3955165  £997.95
# 5   https://www.hotukdeals.com/visit/thread/3955016    £4.79
# 6   https://www.hotukdeals.com/visit/thread/3955143  £130.35
# 7   https://www.hotukdeals.com/visit/thread/3955146   £55.16
# 8   https://www.hotukdeals.com/visit/thread/3955127  £178.50
# 9   https://www.hotukdeals.com/visit/thread/3955065   £97.49
# 10  https://www.hotukdeals.com/visit/thread/3955113    £6.63
# 11  https://www.hotukdeals.com/visit/thread/3955083  £289.76
# 12  https://www.hotukdeals.com/visit/thread/3955034  £306.05
# 13  https://www.hotukdeals.com/visit/thread/3955053  £482.12
# 14  https://www.hotukdeals.com/visit/thread/3954979   £19.99
# 15  https://www.hotukdeals.com/visit/thread/3955017     £174
# 16  https://www.hotukdeals.com/visit/thread/3954904     £999
# 17  https://www.hotukdeals.com/visit/thread/3954963     £275
# 18  https://www.hotukdeals.com/visit/thread/3954974      £60
# 19                                                      £249
# Saved Data in CSV!!
