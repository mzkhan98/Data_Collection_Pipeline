# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time, datetime
import pandas as pd
import os
import boto3
import logging
from botocore.exceptions import ClientError
from sqlalchemy import create_engine





#------------- Scraper Class---------------
class Scraper: 

    #------------- Initiate Chrome Browser---------------
    def __init__(self,url:str = 'https://www.hotukdeals.com/tag/electronics?page=1'):
        self.listofdict = list()
        options = webdriver.ChromeOptions() 
        options.add_argument("start-maximized")
        options.add_experimental_option("excludeSwitches", ["enable-automation"])
        options.add_experimental_option('useAutomationExtension', False)
        options.add_argument('--disable-blink-features=AutomationControlled')
        prefs = {"profile.default_content_setting_values.notifications" : 2}
        options.add_experimental_option("prefs",prefs)
        self.driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
        self.driver.get(url)
        self.s3_client = boto3.client('s3', aws_access_key_id ='',aws_secret_access_key = '', region_name = 'eu-west-2')

    #------------- Accept the Cookies---------------
    def accecept_cookies(self):
        try:
            time.sleep(5)
            self.driver.find_element(By.XPATH,'//button[@data-t="acceptAllBtn"]').click()
        except TimeoutException:
            print('No Cookies Found')

    #------------- Data Scrape from Container & Move to Next Page---------------
    def find_container(self):
        driver = self.driver
        time.sleep(5)
        #count the number of pages
        count = 0
        for pagenum in range(1,501):
            driver.get(f'https://www.hotukdeals.com/tag/electronics?page={pagenum}')
            time.sleep(5)
            #list the page container
            productcontainer = driver.find_elements(By.XPATH, '//article[@data-t="thread"]')
            print(len(productcontainer))        
            for singleproduct in productcontainer: 
                #dict to store data temporary          
                datadict = dict()
                try:datadict['Image'] = singleproduct.find_element(By.XPATH, './/img').get_attribute('src')
                except:datadict['Image'] = ''
                try:datadict['Title'] = singleproduct.find_element(By.XPATH, './/strong[@class="thread-title "]/a').text
                except:datadict['Title'] = ''
                try:datadict['Link'] = singleproduct.find_element(By.XPATH, './/a[@rel="nofollow noopener"]').get_attribute('href')
                except:
                    try:datadict['Link'] = singleproduct.find_element(By.XPATH, './/a[@rel="nofollow"]').get_attribute('href')
                    except:datadict['Link'] = ''
                try:datadict['Price'] = singleproduct.find_element(By.XPATH, './/span[@class="overflow--wrap-off"]/span').text
                except:datadict['Price'] = ''
                print(datadict)
                #append data in main list
                self.listofdict.append(datadict)
            #add the value for page number counting
            count+= 1
            #here you can set number of pages
            if count == 1:
                break
        time.sleep(5)
        driver.quit()
    
    #------------- Save Data ---------------
    def save_data(self):
        date = datetime.datetime.now().strftime("%d-%m-%Y-%H-%M-%S")
        df = pd.DataFrame.from_dict(self.listofdict)
        print('\n\n  ************DATA FRAME**************')
        print(df)
        df.to_csv(f'HotukDeals-{date}.csv',index=False)
        df.to_json(f'HotukDeals-{date}.json') 
        df.to_json(f'HotukDealsData.json')       
        print('Saved Data in CSV!!')
        print('Saved Data in JSON!!')
    
    
    def upload_file(self):
        

        self.session = boto3.Session(
        aws_access_key_id= '',
        aws_secret_access_key='',
        region_name= ''
        )
        
        response = self.s3_client.upload_file(
            'HotukDealsData.json', 'dealsuk2022', 'HotukDealsData.json')
        s3 = self.session.resource('s3')
        
        s3.meta.client.upload_file('/Documents/UNI/AI/Data_Collection_Pipeline/HotukDealsData.json','HotukDealsData.json')
        s3.Bucket('dealsuk2022').upload_file('/Documents/UNI/AI/Data_Collection_Pipeline/HotukDealsData.json','HotukDealsData.json')

    def upload_to_RDS(self):
        pass

        
        #bucket = s3.Bucket('dealsuk2022')

        #for subdir,dirs, files in os.walk(path):
            #for file in files:
                #full_path = os.path.join(subdir, file)
                #with open(full_path, 'rb') as data:
                    #bucket.put_object(Key = full_path[len(path)+1:], Body=data)

        #s3.upload_file('HotukDealsData.json', 'dealsuk2022', 'data')
        
        

        #s3 = boto3.client('s3')
        #s3.upload_file('/Documents/UNI/AI/Data_Collection_Pipeline/HotukDealsData.json','dealsuk2022', 'data')
        
        
        
        #if object_name is None:
            #object_name = os.path.basename(HotukDealsData.json)
        
        #s3_client = boto3.client('s3')
        #try:
            #response =s3_client.upload_file('~/Documents/UNI/AI/Data_Collection_Pipeline/HotukDealsData.json, bucket, object_name')
        #except ClientError as e:
            #logging.error(e)
            #return False
        #return True


    
    
       
        
            



if __name__ == "__main__":
    bot = Scraper()
    bot.accecept_cookies()
    try:
        bot.find_container()
        bot.save_data()
        bot.upload_file()
    except:
        bot.save_data()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/home/zain/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache
# /tmp/ipykernel_19530/3609115530.py:30: DeprecationWarning: use options instead of chrome_options
#   self.driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
# 20
# {'Image': 'https://images.hotukdeals.com/threads/raw/hsNSl/3955999_1/re/300x300/qt/60/3955999_1.jpg', 'Title': 'Realme GT Neo 3T, 8+128GB, Sim Free Unlocked 5G Smartphone, 6.62” AMOLED Display, Snapdragon 870 - £339 Delivered / Gt 3 Neo £549 @ Efones', 'Link': 'https://www.hotukdeals.com/visit/thread/3955999', 'Price': '£339'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/BQGUd/3955958_1/re/300x300/qt/60/3955958_1.jpg', 'Title': 'Samsung Galaxy Watch4 Green/ Silver £139 with voucher / £69 with student prime and trade in at Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955958', 'Price': '£139'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/oPpc5/3955900_1/re/300x300/qt/60/3955900_1.jpg', 'Title': 'Drayton Wiser Smart Heating Radiator Thermostat Works with Amazon Alexa, Google Home, IFTTT £36 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955900', 'Price': '£36'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/GNfjB/3955896_1/re/300x300/qt/60/3955896_1.jpg', 'Title': 'IdeaPad 5i Chromebook Gen 6 (14" Touchscreen, Intel) - £229.99 @ Lenovo', 'Link': 'https://www.hotukdeals.com/visit/thread/3955896', 'Price': '£229.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/nDxJP/3955910_1/re/300x300/qt/60/3955910_1.jpg', 'Title': 'KIOXIA 64GB EXCERIA microSD Memory Card U1 Class 10 100MB/s Max Read Speed £5.39 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955910', 'Price': '£5.39'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/8Qr9O/3955869_1/re/300x300/qt/60/3955869_1.jpg', 'Title': 'ThinkPad X1 Fold for £899.99 @ Lenovo', 'Link': 'https://www.hotukdeals.com/visit/thread/3955869', 'Price': '£899.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/ga4gI/3955880_1/re/300x300/qt/60/3955880_1.jpg', 'Title': 'OPPO Find X3 Neo - 256 GB + 12 GB RAM Galactic Silver Unlocked - Opened Never Used - £275 @ miandmore / ebay', 'Link': 'https://www.hotukdeals.com/visit/thread/3955880', 'Price': '£275'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/1MFDp/3955608_1/re/300x300/qt/60/3955608_1.jpg', 'Title': 'HONOR X7 4G 4/128gb + free Smartband 6 + TPU case - £159.99 @ Honor', 'Link': 'https://www.hotukdeals.com/visit/thread/3955608', 'Price': '£159.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/pOJIK/3955866_1/re/300x300/qt/60/3955866_1.jpg', 'Title': 'IdeaPad Flex 3 (11", AMD) for £149.99 @ Lenovo', 'Link': 'https://www.hotukdeals.com/visit/thread/3955866', 'Price': '£149.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/KO0s8/3955557_1/re/300x300/qt/60/3955557_1.jpg', 'Title': 'Anker USB C Hub, PowerExpand+ 7-in-1 USB C Hub Adapter, with 4K HDMI, 100W Power Delivery £31.44 delivered @ Amazon/AnkerDirect', 'Link': 'https://www.hotukdeals.com/visit/thread/3955557', 'Price': '£31.44'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/KD5ET/3955855_1/re/300x300/qt/60/3955855_1.jpg', 'Title': 'Denon PMA-900HNE Integrated Network HiFi Amplifier £518.40 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955855', 'Price': '£518.40'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/79vYI/3955851_1/re/300x300/qt/60/3955851_1.jpg', 'Title': 'Samsung UK Travel Adaptor (45W with USB type C Cable) Black, EP-TA845XBEGGB - £18.81 @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955851', 'Price': '£18.81'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/KtGjN/3955621_1/re/300x300/qt/60/3955621_1.jpg', 'Title': 'AWD-IT Hero 6, Intel Core i5, 16GB RAM, 240GB SSD, 2TB HDD, NVIDIA GeForce RTX 3060 Desktop + Accessories - £849.99 @ Costco', 'Link': 'https://www.hotukdeals.com/visit/thread/3955621', 'Price': '£849.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/IeXQ1/3955820_1/re/300x300/qt/60/3955820_1.jpg', 'Title': '5TB - WD Elements Portable Hard Drive (Recertified) - £61.20 delivered Using Code @ WDShop', 'Link': 'https://www.hotukdeals.com/visit/thread/3955820', 'Price': '£61.20'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/28iBv/3955819_1/re/300x300/qt/60/3955819_1.jpg', 'Title': 'Samsung Galaxy Watch4 Classic 46mm - £194.99 / £69 With Voucher (Selected Accounts) Student Prime & Trade Cashback @ Amazon', 'Link': 'https://www.hotukdeals.com/visit/thread/3955819', 'Price': '£194.99'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/9TYIL/3955809_1/re/300x300/qt/60/3955809_1.jpg', 'Title': 'Razer Anzu Smart Glasses: Blue Light Filtering & Polarized Sunglass Lenses £54.36 @ Amazon US', 'Link': 'https://www.hotukdeals.com/visit/thread/3955809', 'Price': '£54.36'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/VMpwK/3955723_1/re/300x300/qt/60/3955723_1.jpg', 'Title': 'Sony WF-1000XM4 Wireless ANC Earphones Black £135.73 / Silver £134.30 (when logging into app first time) - Delivered @ Amazon Spain', 'Link': 'https://www.hotukdeals.com/visit/thread/3955723', 'Price': '£134.30'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/9un9O/3955662_1/re/300x300/qt/60/3955662_1.jpg', 'Title': 'Dell Inspiron 14, 5000-series. Ryzen 5 5500U, 1 x 8GB RAM (upgradeable), 256GB NVMe SSD - £426.55 with code @ Dell', 'Link': 'https://www.hotukdeals.com/visit/thread/3955662', 'Price': '£426.55'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/n5iJ4/3955700_1/re/300x300/qt/60/3955700_1.jpg', 'Title': 'Apple airtag 4 pack (1st time app code) - £72.03 delivered @ Amazon Germany', 'Link': 'https://www.hotukdeals.com/visit/thread/3955700', 'Price': '£72.03'}
# {'Image': 'https://images.hotukdeals.com/threads/raw/g3JBZ/3955668_1/re/300x300/qt/60/3955668_1.jpg', 'Title': 'Aukey EP-T25 Bluetooth 5.0 IPX5 Water Resistance True Wireless Earbuds - Black - £11.99 Delivered With Code @ MyMemory', 'Link': 'https://www.hotukdeals.com/visit/thread/3955668', 'Price': '£11.99'}
#
#
#   ************DATA FRAME**************
#                                                 Image  \
# 0   https://images.hotukdeals.com/threads/raw/hsNS...
# 1   https://images.hotukdeals.com/threads/raw/BQGU...
# 2   https://images.hotukdeals.com/threads/raw/oPpc...
# 3   https://images.hotukdeals.com/threads/raw/GNfj...
# 4   https://images.hotukdeals.com/threads/raw/nDxJ...
# 5   https://images.hotukdeals.com/threads/raw/8Qr9...
# 6   https://images.hotukdeals.com/threads/raw/ga4g...
# 7   https://images.hotukdeals.com/threads/raw/1MFD...
# 8   https://images.hotukdeals.com/threads/raw/pOJI...
# 9   https://images.hotukdeals.com/threads/raw/KO0s...
# 10  https://images.hotukdeals.com/threads/raw/KD5E...
# 11  https://images.hotukdeals.com/threads/raw/79vY...
# 12  https://images.hotukdeals.com/threads/raw/KtGj...
# 13  https://images.hotukdeals.com/threads/raw/IeXQ...
# 14  https://images.hotukdeals.com/threads/raw/28iB...
# 15  https://images.hotukdeals.com/threads/raw/9TYI...
# 16  https://images.hotukdeals.com/threads/raw/VMpw...
# 17  https://images.hotukdeals.com/threads/raw/9un9...
# 18  https://images.hotukdeals.com/threads/raw/n5iJ...
# 19  https://images.hotukdeals.com/threads/raw/g3JB...
#
#                                                 Title  \
# 0   Realme GT Neo 3T, 8+128GB, Sim Free Unlocked 5...
# 1   Samsung Galaxy Watch4 Green/ Silver £139 with ...
# 2   Drayton Wiser Smart Heating Radiator Thermosta...
# 3   IdeaPad 5i Chromebook Gen 6 (14" Touchscreen, ...
# 4   KIOXIA 64GB EXCERIA microSD Memory Card U1 Cla...
# 5               ThinkPad X1 Fold for £899.99 @ Lenovo
# 6   OPPO Find X3 Neo - 256 GB + 12 GB RAM Galactic...
# 7   HONOR X7 4G 4/128gb + free Smartband 6 + TPU c...
# 8      IdeaPad Flex 3 (11", AMD) for £149.99 @ Lenovo
# 9   Anker USB C Hub, PowerExpand+ 7-in-1 USB C Hub...
# 10  Denon PMA-900HNE Integrated Network HiFi Ampli...
# 11  Samsung UK Travel Adaptor (45W with USB type C...
# 12  AWD-IT Hero 6, Intel Core i5, 16GB RAM, 240GB ...
# 13  5TB - WD Elements Portable Hard Drive (Recerti...
# 14  Samsung Galaxy Watch4 Classic 46mm - £194.99 /...
# 15  Razer Anzu Smart Glasses: Blue Light Filtering...
# 16  Sony WF-1000XM4 Wireless ANC Earphones Black £...
# 17  Dell Inspiron 14, 5000-series. Ryzen 5 5500U, ...
# 18  Apple airtag 4 pack (1st time app code) - £72....
# 19  Aukey EP-T25 Bluetooth 5.0 IPX5 Water Resistan...
#
#                                                Link    Price
# 0   https://www.hotukdeals.com/visit/thread/3955999     £339
# 1   https://www.hotukdeals.com/visit/thread/3955958     £139
# 2   https://www.hotukdeals.com/visit/thread/3955900      £36
# 3   https://www.hotukdeals.com/visit/thread/3955896  £229.99
# 4   https://www.hotukdeals.com/visit/thread/3955910    £5.39
# 5   https://www.hotukdeals.com/visit/thread/3955869  £899.99
# 6   https://www.hotukdeals.com/visit/thread/3955880     £275
# 7   https://www.hotukdeals.com/visit/thread/3955608  £159.99
# 8   https://www.hotukdeals.com/visit/thread/3955866  £149.99
# 9   https://www.hotukdeals.com/visit/thread/3955557   £31.44
# 10  https://www.hotukdeals.com/visit/thread/3955855  £518.40
# 11  https://www.hotukdeals.com/visit/thread/3955851   £18.81
# 12  https://www.hotukdeals.com/visit/thread/3955621  £849.99
# 13  https://www.hotukdeals.com/visit/thread/3955820   £61.20
# 14  https://www.hotukdeals.com/visit/thread/3955819  £194.99
# 15  https://www.hotukdeals.com/visit/thread/3955809   £54.36
# 16  https://www.hotukdeals.com/visit/thread/3955723  £134.30
# 17  https://www.hotukdeals.com/visit/thread/3955662  £426.55
# 18  https://www.hotukdeals.com/visit/thread/3955700   £72.03
# 19  https://www.hotukdeals.com/visit/thread/3955668   £11.99
# Saved Data in CSV!!
# Saved Data in JSON!!
#
#
#   ************DATA FRAME**************
#                                                 Image  \
# 0   https://images.hotukdeals.com/threads/raw/hsNS...
# 1   https://images.hotukdeals.com/threads/raw/BQGU...
# 2   https://images.hotukdeals.com/threads/raw/oPpc...
# 3   https://images.hotukdeals.com/threads/raw/GNfj...
# 4   https://images.hotukdeals.com/threads/raw/nDxJ...
# 5   https://images.hotukdeals.com/threads/raw/8Qr9...
# 6   https://images.hotukdeals.com/threads/raw/ga4g...
# 7   https://images.hotukdeals.com/threads/raw/1MFD...
# 8   https://images.hotukdeals.com/threads/raw/pOJI...
# 9   https://images.hotukdeals.com/threads/raw/KO0s...
# 10  https://images.hotukdeals.com/threads/raw/KD5E...
# 11  https://images.hotukdeals.com/threads/raw/79vY...
# 12  https://images.hotukdeals.com/threads/raw/KtGj...
# 13  https://images.hotukdeals.com/threads/raw/IeXQ...
# 14  https://images.hotukdeals.com/threads/raw/28iB...
# 15  https://images.hotukdeals.com/threads/raw/9TYI...
# 16  https://images.hotukdeals.com/threads/raw/VMpw...
# 17  https://images.hotukdeals.com/threads/raw/9un9...
# 18  https://images.hotukdeals.com/threads/raw/n5iJ...
# 19  https://images.hotukdeals.com/threads/raw/g3JB...
#
#                                                 Title  \
# 0   Realme GT Neo 3T, 8+128GB, Sim Free Unlocked 5...
# 1   Samsung Galaxy Watch4 Green/ Silver £139 with ...
# 2   Drayton Wiser Smart Heating Radiator Thermosta...
# 3   IdeaPad 5i Chromebook Gen 6 (14" Touchscreen, ...
# 4   KIOXIA 64GB EXCERIA microSD Memory Card U1 Cla...
# 5               ThinkPad X1 Fold for £899.99 @ Lenovo
# 6   OPPO Find X3 Neo - 256 GB + 12 GB RAM Galactic...
# 7   HONOR X7 4G 4/128gb + free Smartband 6 + TPU c...
# 8      IdeaPad Flex 3 (11", AMD) for £149.99 @ Lenovo
# 9   Anker USB C Hub, PowerExpand+ 7-in-1 USB C Hub...
# 10  Denon PMA-900HNE Integrated Network HiFi Ampli...
# 11  Samsung UK Travel Adaptor (45W with USB type C...
# 12  AWD-IT Hero 6, Intel Core i5, 16GB RAM, 240GB ...
# 13  5TB - WD Elements Portable Hard Drive (Recerti...
# 14  Samsung Galaxy Watch4 Classic 46mm - £194.99 /...
# 15  Razer Anzu Smart Glasses: Blue Light Filtering...
# 16  Sony WF-1000XM4 Wireless ANC Earphones Black £...
# 17  Dell Inspiron 14, 5000-series. Ryzen 5 5500U, ...
# 18  Apple airtag 4 pack (1st time app code) - £72....
# 19  Aukey EP-T25 Bluetooth 5.0 IPX5 Water Resistan...
#
#                                                Link    Price
# 0   https://www.hotukdeals.com/visit/thread/3955999     £339
# 1   https://www.hotukdeals.com/visit/thread/3955958     £139
# 2   https://www.hotukdeals.com/visit/thread/3955900      £36
# 3   https://www.hotukdeals.com/visit/thread/3955896  £229.99
# 4   https://www.hotukdeals.com/visit/thread/3955910    £5.39
# 5   https://www.hotukdeals.com/visit/thread/3955869  £899.99
# 6   https://www.hotukdeals.com/visit/thread/3955880     £275
# 7   https://www.hotukdeals.com/visit/thread/3955608  £159.99
# 8   https://www.hotukdeals.com/visit/thread/3955866  £149.99
# 9   https://www.hotukdeals.com/visit/thread/3955557   £31.44
# 10  https://www.hotukdeals.com/visit/thread/3955855  £518.40
# 11  https://www.hotukdeals.com/visit/thread/3955851   £18.81
# 12  https://www.hotukdeals.com/visit/thread/3955621  £849.99
# 13  https://www.hotukdeals.com/visit/thread/3955820   £61.20
# 14  https://www.hotukdeals.com/visit/thread/3955819  £194.99
# 15  https://www.hotukdeals.com/visit/thread/3955809   £54.36
# 16  https://www.hotukdeals.com/visit/thread/3955723  £134.30
# 17  https://www.hotukdeals.com/visit/thread/3955662  £426.55
# 18  https://www.hotukdeals.com/visit/thread/3955700   £72.03
# 19  https://www.hotukdeals.com/visit/thread/3955668   £11.99
# Saved Data in CSV!!
# Saved Data in JSON!!
